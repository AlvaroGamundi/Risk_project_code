# %% [markdown]
# # MODELIZACIÓN CLASIFICACIÓN PROBABILITY OF DEFAULT

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report

from sklearn.metrics import RocCurveDisplay
import scikitplot as skplt
from yellowbrick.classifier import discrimination_threshold

#Autocompletar rápido
# %config IPCompleter.greedy=True

#Desactivar la notación científica
pd.options.display.float_format = '{:.2f}'.format

#Desactivar los warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/alvar/Proyectos ML/03_RIESGOS'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre = 'df_tablon_pd.pickle'

# %% [markdown]
# Cargar los datos.

# %%
df = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre)

# %% [markdown]
# a_eliminar=['vivienda_OWN','ingresos_verificados_Source Verified','finalidad_home_improvement','finalidad_moving','finalidad_vacation','num_hipotecas_mms','antiguedad_empleo_oe_mms','rating_oe_mms','imp_cuota_mms']
# df=df.drop(columns=a_eliminar)

# %%
x = df.drop(columns='target_pd')
y = df.target_pd

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 139482 entries, 137387967 to 94394801
# Data columns (total 32 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   ingresos_verificados_Not Verified     139482 non-null  float64
#  1   ingresos_verificados_Source Verified  139482 non-null  float64
#  2   ingresos_verificados_Verified         139482 non-null  float64
#  3   vivienda_MORTGAGE                     139482 non-null  float64
#  4   vivienda_OWN                          139482 non-null  float64
#  5   vivienda_RENT                         139482 non-null  float64
#  6   finalidad_car                         139482 non-null  float64
#  7   finalidad_credit_card                 139482 non-null  float64
#  8   finalidad_debt_consolidation          139482 non-null  float64
#  9   finalidad_home_improvement            139482 non-null  float64
#  10  finalidad_house                       139482 non-null  float64
#  11  finalidad_major_purchase              139482 non-null  float64
#  12  finalidad_medical                     139482 non-null  float64
#  13  finalidad_moving                      139482 non-null  float64
#  14  finalidad_other                       139482 non-null  float64
#  15  finalidad_small_business              139482 non-null  float64
#  16  finalidad_vacation                    139482 non-null  float64
#  17  num_cuotas_ 36 months                 139482 non-null  float64
#  18  num_cuotas_ 60 months                 139482 non-null  float64
#  19  antiguedad_empleo_oe_mms              139482 non-null  float64
#  20  rating_oe_mms                         139482 non-null  float64
#  21  ingresos_mms                          139482 non-null  float64
#  22  dti_mms                               139482 non-null  float64
#  23  num_lineas_credito_mms                139482 non-null  float64
#  24  porc_uso_revolving_mms                139482 non-null  float64
#  25  principal_mms                         139482 non-null  float64
#  26  tipo_interes_mms                      139482 non-null  float64
#  27  imp_cuota_mms                         139482 non-null  float64
#  28  num_hipotecas_mms                     139482 non-null  float64
#  29  porc_tarjetas_75p_mms                 139482 non-null  float64
#  30  num_cancelaciones_12meses             139482 non-null  int32
#  31  num_derogatorios                      139482 non-null  int32
# dtypes: float64(30), int32(2)
# memory usage: 34.1 MB

# %% [markdown]
# ## MODELIZAR

# %% [markdown]
# ### Reservar el dataset de validacion

# %%
train_x,val_x,train_y,val_y = train_test_split(x,y,test_size=0.3)

# %% [markdown]
# ### Crear el pipe y el diccionario de algorimos, parámetros y valores a testar

# %% [markdown]
# Modificar para dejar solo los algoritmos que se quieran testar.
#
# Modificar los parámetros.

# %%
pipe = Pipeline([('algoritmo',LogisticRegression())])

grid = [{'algoritmo': [LogisticRegression(solver = 'saga', n_jobs=-1)],
         'algoritmo__penalty': ['elasticnet', 'l1', 'l2'],
         'algoritmo__C': [0,0.25,0.5,0.75,1]}
       ]

# %% [markdown]
# ### Optimizar los hiper parámetros

# %% [markdown]
# Elegir si se quiere usar grid search o random search.
#
# Comentar la opción que no se vaya a usar.

# %% [markdown]
# ####  Con grid search

# %%
grid_search = GridSearchCV(estimator= pipe, 
                           param_grid = grid, 
                           cv = 5, 
                           scoring = 'roc_auc',
                           verbose = 0,
                           n_jobs = -1)

modelo = grid_search.fit(train_x,train_y)

# %%
salida = pd.DataFrame(grid_search.cv_results_).sort_values(by = 'rank_test_score').reset_index(drop=True).head(5)
salida
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0           2.30          0.18             0.02            0.00
# 1           6.05          0.26             0.01            0.00
# 2           2.30          0.10             0.02            0.00
# 3           6.14          0.10             0.02            0.00
# 4           2.19          0.22             0.02            0.00
#
#                                 param_algoritmo  param_algoritmo__C  \
# 0  LogisticRegression(n_jobs=-1, solver='saga')                1.00
# 1  LogisticRegression(n_jobs=-1, solver='saga')                1.00
# 2  LogisticRegression(n_jobs=-1, solver='saga')                0.75
# 3  LogisticRegression(n_jobs=-1, solver='saga')                0.75
# 4  LogisticRegression(n_jobs=-1, solver='saga')                0.50
#
#   param_algoritmo__penalty                                             params  \
# 0                       l1  {'algoritmo': LogisticRegression(n_jobs=-1, so...
# 1                       l2  {'algoritmo': LogisticRegression(n_jobs=-1, so...
# 2                       l1  {'algoritmo': LogisticRegression(n_jobs=-1, so...
# 3                       l2  {'algoritmo': LogisticRegression(n_jobs=-1, so...
# 4                       l1  {'algoritmo': LogisticRegression(n_jobs=-1, so...
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0               0.69               0.70               0.70               0.70
# 1               0.69               0.70               0.70               0.70
# 2               0.69               0.70               0.70               0.70
# 3               0.69               0.70               0.70               0.70
# 4               0.69               0.70               0.70               0.70
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0               0.71             0.70            0.01                1
# 1               0.71             0.70            0.01                2
# 2               0.71             0.70            0.01                3
# 3               0.71             0.70            0.01                4
# 4               0.71             0.70            0.01                5

# %% [markdown]
# Vemos que el resultados del auc es el mismo en todas las primeras configuraciones.
#
# Y reentreamos el modelo con esa configuración.

# %%
#Instanciar
rl = LogisticRegression(solver = 'saga', n_jobs=-1, C = 1, penalty = 'l1')

#Entrenar
rl.fit(train_x,train_y)
# Out:
# LogisticRegression(C=1, n_jobs=-1, penalty='l1', solver='saga')

# %% [markdown]
# Podemos revisar los coefecientes para ver los que son cero y las variables más importantes.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear el DataFrame de coeficientes si no lo tienes ya
coeficientes = pd.DataFrame(data=rl.coef_, columns=rl.feature_names_in_).stack().droplevel(level=0).sort_values()

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
sns.barplot(x=coeficientes.values, y=coeficientes.index, palette="viridis")

# Agregar títulos y etiquetas
plt.title("Logistic Regression Model Coefficients", fontsize=14)
plt.xlabel("Coefficient Value", fontsize=12)
plt.ylabel("Variables", fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
coeficientes = pd.DataFrame(data = rl.coef_, columns = rl.feature_names_in_).stack().droplevel(level = 0).sort_values()
coeficientes
# Out:
# rating_oe_mms                          -4.50
# tipo_interes_mms                       -2.44
# ingresos_mms                           -1.44
# principal_mms                          -1.42
# ingresos_verificados_Not Verified      -0.27
# finalidad_vacation                     -0.19
# vivienda_MORTGAGE                      -0.14
# finalidad_other                        -0.10
# finalidad_house                        -0.07
# finalidad_car                          -0.07
# finalidad_credit_card                  -0.02
# num_cuotas_ 36 months                  -0.01
# ingresos_verificados_Source Verified   -0.00
# finalidad_home_improvement              0.00
# vivienda_OWN                            0.00
# dti_mms                                 0.01
# antiguedad_empleo_oe_mms                0.03
# finalidad_debt_consolidation            0.06
# num_hipotecas_mms                       0.08
# num_cancelaciones_12meses               0.08
# ingresos_verificados_Verified           0.09
# finalidad_medical                       0.10
# vivienda_RENT                           0.14
# finalidad_moving                        0.15
# porc_tarjetas_75p_mms                   0.15
# num_derogatorios                        0.16
# finalidad_major_purchase                0.16
# porc_uso_revolving_mms                  0.21
# num_cuotas_ 60 months                   0.25
# finalidad_small_business                0.27
# num_lineas_credito_mms                  1.53
# imp_cuota_mms                           2.03
# dtype: float64

# %%
def correlaciones_fuertes(df, lim_inf = 0.3, lim_sup = 1,drop_dupli=True):
    #Calcula la matriz de correlación
    c = df.corr().abs()
    #Lo pasa todo a filas
    c= c.unstack()
    #Pasa el índice a columnas y le pone nombres
    c = pd.DataFrame(c).reset_index()
    c.columns = ['var1','var2','corr']
    #A dataframe, filtra limites y ordena en descendiente
    c = c.loc[(c['corr'] > lim_inf) &  (c['corr'] < lim_sup),:].sort_values(by = 'corr', ascending=False)
    #Desduplica las correlaciones (o no si drop_dupli es False)
    c = c if drop_dupli == False else c.drop_duplicates(subset = ['corr'])
    #Devuelve la salida
    return(c)

# %%
cor_finales = correlaciones_fuertes(x)

# %%
cor_finales.head(50)
# Out:
#                                      var1  \
# 852                      tipo_interes_mms
# 889                         imp_cuota_mms
# 163                         vivienda_RENT
# 952                 porc_tarjetas_75p_mms
# 263          finalidad_debt_consolidation
# 1       ingresos_verificados_Not Verified
# 34   ingresos_verificados_Source Verified
# 124                     vivienda_MORTGAGE
# 188                         vivienda_RENT
# 697                          ingresos_mms
# 64          ingresos_verificados_Verified
# 885                         imp_cuota_mms
# 569                 num_cuotas_ 36 months
# 564                 num_cuotas_ 36 months
# 596                 num_cuotas_ 60 months
# 849                      tipo_interes_mms
# 602                 num_cuotas_ 60 months
# 131                          vivienda_OWN
# 700                          ingresos_mms
# 296            finalidad_home_improvement
#
#                                      var2  corr
# 852                         rating_oe_mms  0.95
# 889                         principal_mms  0.95
# 163                     vivienda_MORTGAGE  0.80
# 952                porc_uso_revolving_mms  0.71
# 263                 finalidad_credit_card  0.62
# 1    ingresos_verificados_Source Verified  0.57
# 34          ingresos_verificados_Verified  0.50
# 124                     num_hipotecas_mms  0.48
# 188                     num_hipotecas_mms  0.45
# 697                         principal_mms  0.45
# 64      ingresos_verificados_Not Verified  0.43
# 885                          ingresos_mms  0.43
# 569                         principal_mms  0.39
# 564                         rating_oe_mms  0.38
# 596                         rating_oe_mms  0.38
# 849                 num_cuotas_ 36 months  0.37
# 602                      tipo_interes_mms  0.37
# 131                     vivienda_MORTGAGE  0.35
# 700                     num_hipotecas_mms  0.31
# 296          finalidad_debt_consolidation  0.30

# %%
df.tipo_interes_mms.value_counts()
# Out:
# 0.26    3372
# 0.00    2939
# 0.34    2677
# 0.22    2662
# 0.24    1986
#         ...
# 0.47       1
# 0.23       1
# 0.29       1
# 0.50       1
# 0.41       1
# Name: tipo_interes_mms, Length: 580, dtype: int64

# %% [markdown]
# **IMPORTANTE**
#
# Vemos cosas raras como que el signo del principal y del tipo de interés son negativos.
#
# Es decir, según el modelo, cuanto menos importe pidas mayor es el riesgo de default.
#
# O cuanto menor es el tipo de interés aplicado mayor es el riesgo de default.
#
# En una situación real podría pasar, pero al menos se necesitaría una explicación convincente.
#
# Nosotros aquí lo daremos por bueno y continuamos.

# %% [markdown]
# ## EVALUAR

# %% [markdown]
# ### Predecir sobre validación

# %%
pred = rl.predict_proba(val_x)[:, 1]

# %% [markdown]
# ### Evaluar sobre validación

# %%
roc_auc_score(val_y, pred)
# Out:
# 0.7042781522884648

# %%
pred
# Out:
# array([0.08365918, 0.19619396, 0.56998719, ..., 0.05939607, 0.09144229,
#        0.11888668])

# %% [markdown]
# ## REPORTING DEL MODELO

# %% [markdown]
# ### Gain Chart

# %%
fig, ax = plt.subplots()

skplt.metrics.plot_cumulative_gain(val_y, modelo.best_estimator_.predict_proba(val_x), ax=ax) 

# Eliminamos la línea de los ceros, que internamente tiene etiqueta 'Class 0'
lines = ax.get_lines()
# Buscar por la etiqueta y eliminar la línea correspondiente
for line in lines:
    if line.get_label() == 'Class 0':
        line.remove()

# Personalizamos la leyenda sin incluir la línea de los ceros
plt.legend(labels=['Modelo'])

# Ahora puedes mostrar el gráfico
plt.show()

# %% [markdown]
# ### Lift Chart

# %%
fig, ax = plt.subplots()

skplt.metrics.plot_lift_curve(val_y, modelo.best_estimator_.predict_proba(val_x), ax=ax) 

# Eliminamos la línea de los ceros, que internamente tiene etiqueta 'Class 0'
lines = ax.get_lines()
# Buscar por la etiqueta y eliminar la línea correspondiente
for line in lines:
    if line.get_label() == 'Class 0':
        line.remove()

# Personalizamos la leyenda sin incluir la línea de los ceros
plt.legend(labels=['Modelo'])

# Ahora puedes mostrar el gráfico
plt.show()

# %% [markdown]
# ### ROC Chart

# %%
fig, ax = plt.subplots()

# Generamos la gráfica ROC
skplt.metrics.plot_roc(val_y, modelo.best_estimator_.predict_proba(val_x), ax=ax)

# Obtenemos todas las líneas y las leyendas
lines = ax.get_lines()

# Recorremos las líneas para eliminar las no deseadas, excepto la línea de la clase 0
for line in lines:
    if 'ROC curve of class 0' in line.get_label():
        line.set_label('Modelo')
    elif line.get_linestyle() != '--':  # Mantenemos la línea punteada pero sin leyenda
        line.set_visible(False)

# Solo añadimos al leyenda la línea de la clase 0 renombrada a 'Modelo'
handles, labels = ax.get_legend_handles_labels()
new_handles = [h for h, l in zip(handles, labels) if l == 'Modelo']
new_labels = ['Modelo']

ax.legend(new_handles, new_labels, loc='best')

# Ahora puedes mostrar el gráfico
plt.show();

# %%
train_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97637 entries, 139891803 to 77239294
# Data columns (total 32 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ingresos_verificados_Not Verified     97637 non-null  float64
#  1   ingresos_verificados_Source Verified  97637 non-null  float64
#  2   ingresos_verificados_Verified         97637 non-null  float64
#  3   vivienda_MORTGAGE                     97637 non-null  float64
#  4   vivienda_OWN                          97637 non-null  float64
#  5   vivienda_RENT                         97637 non-null  float64
#  6   finalidad_car                         97637 non-null  float64
#  7   finalidad_credit_card                 97637 non-null  float64
#  8   finalidad_debt_consolidation          97637 non-null  float64
#  9   finalidad_home_improvement            97637 non-null  float64
#  10  finalidad_house                       97637 non-null  float64
#  11  finalidad_major_purchase              97637 non-null  float64
#  12  finalidad_medical                     97637 non-null  float64
#  13  finalidad_moving                      97637 non-null  float64
#  14  finalidad_other                       97637 non-null  float64
#  15  finalidad_small_business              97637 non-null  float64
#  16  finalidad_vacation                    97637 non-null  float64
#  17  num_cuotas_ 36 months                 97637 non-null  float64
#  18  num_cuotas_ 60 months                 97637 non-null  float64
#  19  antiguedad_empleo_oe_mms              97637 non-null  float64
#  20  rating_oe_mms                         97637 non-null  float64
#  21  ingresos_mms                          97637 non-null  float64
#  22  dti_mms                               97637 non-null  float64
#  23  num_lineas_credito_mms                97637 non-null  float64
#  24  porc_uso_revolving_mms                97637 non-null  float64
#  25  principal_mms                         97637 non-null  float64
#  26  tipo_interes_mms                      97637 non-null  float64
#  27  imp_cuota_mms                         97637 non-null  float64
#  28  num_hipotecas_mms                     97637 non-null  float64
#  29  porc_tarjetas_75p_mms                 97637 non-null  float64
#  30  num_cancelaciones_12meses             97637 non-null  int32
#  31  num_derogatorios                      97637 non-null  int32
# dtypes: float64(30), int32(2)
# memory usage: 23.8 MB
